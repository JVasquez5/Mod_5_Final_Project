# %% [markdown]
# # Final Project Submission
#
# * Student name: Jonathan Vasquez
# * Student pace: Full Time
# * Scheduled project review date/time:
# * Instructor name: Fangfang Lee, SeanAbu Wilson, Matthew Wasserman
# * Blog post URL:

# %% [markdown]
# # Importing Libraries

# %%
import matplotlib.pyplot as plt
import numpy as np
import os, shutil
import tensorflow as tf
import pandas as pd
import cv2
import glob
import random
import keras
import PIL.Image
import matplotlib.image as mpimg
import re

from keras import models, layers
from keras.models import Model, load_model, Sequential
from keras.preprocessing.image import ImageDataGenerator, array_to_img, img_to_array, load_img
from keras.layers import Dense, Dropout, Flatten, ZeroPadding2D, Conv2D, MaxPooling2D, GlobalAveragePooling2D
from keras.utils import to_categorical 
from keras.optimizers import Adam, SGD, RMSprop 
from keras.callbacks import ModelCheckpoint, EarlyStopping
from keras.preprocessing.image import load_img
from keras.preprocessing.image import img_to_array
from keras.applications import vgg16
from keras.applications.vgg16 import preprocess_input
from keras.applications.vgg16 import decode_predictions
from keras.applications.vgg16 import VGG16

from IPython.display import display
from random import randint
from pathlib import Path
from PIL import Image
from glob import glob 
import splitfolders 

from bokeh.models import ColumnDataSource, HoverTool, Panel, FactorRange
from bokeh.plotting import figure
from bokeh.io import output_notebook, show, output_file
from bokeh.palettes import Spectral6

from sklearn.metrics import confusion_matrix, f1_score
from sklearn.metrics import classification_report
from sklearn.metrics import confusion_matrix, f1_score

np.random.seed(123)

# %% [markdown]
# # Importing Data

# %%
#Setting the Base Directory
root_dir = "mol_images/"
root_dir
# Out:
# 'mol_images/'

# %%
##Converting PNG to JPG. NO NEED TO RUN AGAIN
#images_shape = []
#for k, image_path in enumerate(glob(root_dir + "*/*")):
#    im = Image.open(image_path)
#    rgb_im = im.convert('RGB')
#    rgb_im.save(image_path.replace("png", "jpg"), quality=95)

# %%
##Split with a ratio. NO NEED TO RUN AGAIN
#splitfolders.ratio(root_dir, output="output", seed=1337, 
#                   ratio=(.8, .1, .1), group_prefix=None) # default values

# %%
train_dir = os.path.join(root_dir, "train/")
test_dir = os.path.join(root_dir, "test/")
val_dir = os.path.join(root_dir, "val/")

# %%
# glob data together to get TOXIC and NOT_TOXIC images
toxic = glob(train_dir + "toxic/*")
not_toxic = glob(test_dir + "not_toxic/*")

# %%
# extract 6 random images from NOT_TOXIC
random_images = [not_toxic[i] for i in range(6)]

print('Display NOT_TOXIC Images')

# adjust the size of the images
plt.figure(figsize=(10,8))

# iterate and plot random images
for i in range(6):
    plt.subplot(3, 3, i + 1)
    img = plt.imread(random_images[i])
    plt.imshow(img, cmap='gray')
    plt.axis('off')
    
# adjust subplot parameters to give specified padding
plt.tight_layout()
# Out:
# Display NOT_TOXIC Images

# %%
# extract 6 random images from TOXIC
random_images = [toxic[i] for i in range(10)]

print('Display TOXIC Images')

# adjust the size of the images
plt.figure(figsize=(10,8))

# iterate and plot random images
for i in range(6):
    plt.subplot(3, 3, i + 1)
    img = plt.imread(random_images[i])
    plt.imshow(img, cmap='gray')
    plt.axis('off')
    
# adjust subplot parameters to give specified padding
plt.tight_layout()
# Out:
# Display TOXIC Images

# %% [markdown]
# # EDA/Data Cleaning

# %%
# let's find out how many images we have in each folder
print("Number of images in Train is {}".format(len(glob(train_dir + "*/*"))))
print("Number of images in Test is {}".format(len(glob(test_dir + "*/*"))))
print("Number of images in Validation is {}".format(len(glob(val_dir + "*/*"))))
# Out:
# Number of images in Train is 11199
# Number of images in Test is 1387
# Number of images in Validation is 1395

# %%
# time to check the distribution of images within each category
Categories = ["Train", "Test", "Validation"]
Subcategories = ['TOXIC', 'NOT_TOXIC']

Train = [5635, 690]
Test = [5564, 697]
Validation = [700, 695]

data = {'Categories':Categories,
        'Train':Train,
        'Test':Test,
        'Validation':Validation}

x = [(categories, subcategories) for categories in Categories for subcategories in Subcategories]
counts = sum(zip(data['Train'], data['Test'], data['Validation']), ())

source = ColumnDataSource(data=dict(x=x, counts=counts, color=Spectral6))

p = figure(x_range=FactorRange(*x), plot_height=600, plot_width=1000, title="Distribution of images with different category",
           tools="hover, pan, box_zoom, wheel_zoom, reset, save", tooltips= ("@x: @counts"))

p.vbar(x='x', top='counts', width=0.9, color='color', legend_field="x", source=source)

p.xgrid.grid_line_color = None
p.legend.orientation = "horizontal"
p.legend.location = "top_center"
output_notebook()
show(p)
# Out:
#     <div class="bk-root">
#         <a href="https://bokeh.org" target="_blank" class="bk-logo bk-logo-small bk-logo-notebook"></a>
#         <span id="1048">Loading BokehJS ...</span>
#     </div>
#   <div class="bk-root" id="09a05708-eacd-4892-a600-a5c6e902170c" data-root-id="1003"></div>

# %% [markdown]
# # Data Processing/Data Augmentation

# %%
# image preprocessing
train_datagen = ImageDataGenerator(rotation_range = 30,
                                   zoom_range = 0.2,
                                   width_shift_range = 0.1,
                                   height_shift_range = 0.1,
                                   horizontal_flip = True,  # horizontal flip added to ensure proper learning
                                   rescale = 1./255)
val_datagen = ImageDataGenerator(rescale = 1./255)
test_datagen = ImageDataGenerator(rescale = 1./255)

# %%
# creation of training, validation, and test sets, including augmentation for the training set
batch_size = 16
training_set = train_datagen.flow_from_directory(train_dir,
                                                 target_size = (300, 300), 
                                                 batch_size = batch_size, 
                                                 class_mode = "binary") #binary class because either evolved or not
val_set = val_datagen.flow_from_directory(val_dir,
                                          target_size = (300, 300),
                                          batch_size = batch_size,
                                          class_mode = 'binary')
test_set = test_datagen.flow_from_directory(test_dir,
                                            target_size = (300, 300),
                                            batch_size = batch_size,
                                            class_mode = 'binary')
# Out:
# Found 11199 images belonging to 2 classes.
# Found 1395 images belonging to 2 classes.
# Found 1387 images belonging to 2 classes.

# %% [markdown]
# # Base CNN

# %%
# vanilla CNN consisting of 2 Zero Padding layers, 2 Convolutional layers, 2 Pooling layers, 
# Flatten, 2 Dense, 2 Dropout, & Output layer
cnn = models.Sequential()
cnn.add(ZeroPadding2D((1,1),input_shape=(300,300,3)))
cnn.add(layers.Conv2D(64, (3, 3), activation='relu'))
cnn.add(layers.MaxPooling2D((2, 2)))
cnn.add(ZeroPadding2D((1,1)))
cnn.add(layers.Conv2D(32, (3, 3), activation='relu'))
cnn.add(layers.MaxPooling2D((2, 2)))
cnn.add(layers.Flatten())
cnn.add(layers.Dense(32, activation='relu'))
cnn.add(Dropout(0.5))
cnn.add(layers.Dense(32, activation='relu'))
cnn.add(Dropout(0.5))
cnn.add(layers.Dense(1, activation='sigmoid'))

# set variable for learning rate so that it can be tuned
optimizer = Adam(lr = 0.001)

cnn.compile(loss='binary_crossentropy', optimizer=optimizer, 
            metrics=['accuracy',tf.keras.metrics.Precision(name='precision'),
                     tf.keras.metrics.Recall(name='recall')])

# %%
cnn.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# zero_padding2d (ZeroPadding2 (None, 302, 302, 3)       0
# _________________________________________________________________
# conv2d (Conv2D)              (None, 300, 300, 64)      1792
# _________________________________________________________________
# max_pooling2d (MaxPooling2D) (None, 150, 150, 64)      0
# _________________________________________________________________
# zero_padding2d_1 (ZeroPaddin (None, 152, 152, 64)      0
# _________________________________________________________________
# conv2d_1 (Conv2D)            (None, 150, 150, 32)      18464
# _________________________________________________________________
# max_pooling2d_1 (MaxPooling2 (None, 75, 75, 32)        0
# _________________________________________________________________
# flatten (Flatten)            (None, 180000)            0
# _________________________________________________________________
# dense (Dense)                (None, 32)                5760032
# _________________________________________________________________
# dropout (Dropout)            (None, 32)                0
# _________________________________________________________________
# dense_1 (Dense)              (None, 32)                1056
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 32)                0
# _________________________________________________________________
# dense_2 (Dense)              (None, 1)                 33
# =================================================================
# Total params: 5,781,377
# Trainable params: 5,781,377
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# # Initial CNN

# %%
cnn1 = cnn.fit(training_set, epochs = 25, workers=-1, 
               validation_data = val_set, shuffle=True)
# Out:
# Epoch 1/25
# 700/700 [==============================] - 838s 1s/step - loss: 0.6959 - accuracy: 0.5055 - precision: 0.5049 - recall: 0.8870 - val_loss: 0.6932 - val_accuracy: 0.4982 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00
# Epoch 2/25
# 700/700 [==============================] - 833s 1s/step - loss: 0.6233 - accuracy: 0.6685 - precision: 0.7776 - recall: 0.4777 - val_loss: 0.6738 - val_accuracy: 0.6143 - val_precision: 0.7368 - val_recall: 0.3600
# Epoch 3/25
# 700/700 [==============================] - 829s 1s/step - loss: 0.5741 - accuracy: 0.7310 - precision: 0.8586 - recall: 0.5572 - val_loss: 0.6529 - val_accuracy: 0.6323 - val_precision: 0.7179 - val_recall: 0.4400
# Epoch 4/25
# 700/700 [==============================] - 830s 1s/step - loss: 0.5744 - accuracy: 0.7310 - precision: 0.8517 - recall: 0.5636 - val_loss: 0.6344 - val_accuracy: 0.6280 - val_precision: 0.7388 - val_recall: 0.4000
# Epoch 5/25
# 700/700 [==============================] - 840s 1s/step - loss: 0.5538 - accuracy: 0.7332 - precision: 0.8513 - recall: 0.5691 - val_loss: 0.6476 - val_accuracy: 0.6165 - val_precision: 0.7434 - val_recall: 0.3600
# Epoch 6/25
# 700/700 [==============================] - 844s 1s/step - loss: 0.5605 - accuracy: 0.7357 - precision: 0.8547 - recall: 0.5720 - val_loss: 0.6230 - val_accuracy: 0.6373 - val_precision: 0.7650 - val_recall: 0.4000
# Epoch 7/25
# 700/700 [==============================] - 850s 1s/step - loss: 0.5536 - accuracy: 0.7347 - precision: 0.8445 - recall: 0.5794 - val_loss: 0.6422 - val_accuracy: 0.6315 - val_precision: 0.7487 - val_recall: 0.4000
# Epoch 8/25
# 700/700 [==============================] - 851s 1s/step - loss: 0.5519 - accuracy: 0.7347 - precision: 0.8563 - recall: 0.5681 - val_loss: 0.6578 - val_accuracy: 0.6272 - val_precision: 0.7064 - val_recall: 0.4400
# Epoch 9/25
# 700/700 [==============================] - 852s 1s/step - loss: 0.5461 - accuracy: 0.7379 - precision: 0.8590 - recall: 0.5732 - val_loss: 0.6326 - val_accuracy: 0.6294 - val_precision: 0.7427 - val_recall: 0.4000
# Epoch 10/25
# 700/700 [==============================] - 863s 1s/step - loss: 0.5489 - accuracy: 0.7387 - precision: 0.8575 - recall: 0.5766 - val_loss: 0.6343 - val_accuracy: 0.6222 - val_precision: 0.7235 - val_recall: 0.4000
# Epoch 11/25
# 700/700 [==============================] - 871s 1s/step - loss: 0.5446 - accuracy: 0.7389 - precision: 0.8522 - recall: 0.5821 - val_loss: 0.6211 - val_accuracy: 0.6459 - val_precision: 0.7910 - val_recall: 0.4000
# Epoch 12/25
# 700/700 [==============================] - 887s 1s/step - loss: 0.5426 - accuracy: 0.7435 - precision: 0.8663 - recall: 0.5796 - val_loss: 0.6283 - val_accuracy: 0.6674 - val_precision: 0.7706 - val_recall: 0.4800
# Epoch 13/25
# 700/700 [==============================] - 851s 1s/step - loss: 0.5465 - accuracy: 0.7398 - precision: 0.8564 - recall: 0.5801 - val_loss: 0.6183 - val_accuracy: 0.6473 - val_precision: 0.7549 - val_recall: 0.4400
# Epoch 14/25
# 700/700 [==============================] - 832s 1s/step - loss: 0.5454 - accuracy: 0.7419 - precision: 0.8636 - recall: 0.5785 - val_loss: 0.6145 - val_accuracy: 0.6674 - val_precision: 0.8105 - val_recall: 0.4400
# Epoch 15/25
# 700/700 [==============================] - 829s 1s/step - loss: 0.5418 - accuracy: 0.7435 - precision: 0.8693 - recall: 0.5769 - val_loss: 0.6674 - val_accuracy: 0.6473 - val_precision: 0.7241 - val_recall: 0.4800
# Epoch 16/25
# 700/700 [==============================] - 828s 1s/step - loss: 0.5446 - accuracy: 0.7419 - precision: 0.8628 - recall: 0.5792 - val_loss: 0.6393 - val_accuracy: 0.6681 - val_precision: 0.7724 - val_recall: 0.4800
# Epoch 17/25
# 700/700 [==============================] - 837s 1s/step - loss: 0.5401 - accuracy: 0.7410 - precision: 0.8663 - recall: 0.5739 - val_loss: 0.6083 - val_accuracy: 0.6824 - val_precision: 0.8096 - val_recall: 0.4800
# Epoch 18/25
# 700/700 [==============================] - 834s 1s/step - loss: 0.5378 - accuracy: 0.7430 - precision: 0.8689 - recall: 0.5762 - val_loss: 0.6132 - val_accuracy: 0.6695 - val_precision: 0.7760 - val_recall: 0.4800
# Epoch 19/25
# 700/700 [==============================] - 833s 1s/step - loss: 0.5323 - accuracy: 0.7420 - precision: 0.8628 - recall: 0.5794 - val_loss: 0.6073 - val_accuracy: 0.6760 - val_precision: 0.8370 - val_recall: 0.4400
# Epoch 20/25
# 700/700 [==============================] - 824s 1s/step - loss: 0.5323 - accuracy: 0.7439 - precision: 0.8750 - recall: 0.5728 - val_loss: 0.6085 - val_accuracy: 0.6609 - val_precision: 0.7918 - val_recall: 0.4400
# Epoch 21/25
# 700/700 [==============================] - 825s 1s/step - loss: 0.5336 - accuracy: 0.7443 - precision: 0.8706 - recall: 0.5776 - val_loss: 0.6158 - val_accuracy: 0.6789 - val_precision: 0.8000 - val_recall: 0.4800
# Epoch 22/25
# 700/700 [==============================] - 827s 1s/step - loss: 0.5288 - accuracy: 0.7464 - precision: 0.8811 - recall: 0.5734 - val_loss: 0.6113 - val_accuracy: 0.6659 - val_precision: 0.8063 - val_recall: 0.4400
# Epoch 23/25
# 700/700 [==============================] - 830s 1s/step - loss: 0.5272 - accuracy: 0.7451 - precision: 0.8763 - recall: 0.5744 - val_loss: 0.6274 - val_accuracy: 0.6774 - val_precision: 0.7962 - val_recall: 0.4800
# Epoch 24/25
# 700/700 [==============================] - 833s 1s/step - loss: 0.5234 - accuracy: 0.7486 - precision: 0.8827 - recall: 0.5771 - val_loss: 0.6121 - val_accuracy: 0.6803 - val_precision: 0.8038 - val_recall: 0.4800
# Epoch 25/25
# 700/700 [==============================] - 831s 1s/step - loss: 0.5265 - accuracy: 0.7447 - precision: 0.8759 - recall: 0.5739 - val_loss: 0.6195 - val_accuracy: 0.6638 - val_precision: 0.8000 - val_recall: 0.4400

# %%
# visualization of loss and accuracy over the 50 epochs
hist_cnn = cnn1.history
loss_values = hist_cnn['loss']
val_loss_values = hist_cnn['val_loss']
acc_values = hist_cnn['accuracy'] 
val_acc_values = hist_cnn['val_accuracy']


epochs = range(1, len(loss_values) + 1)

plt.figure(figsize=(15,4))
plt.subplot(121)
plt.plot(epochs, loss_values, 'g.', label='Training loss')
plt.plot(epochs, val_loss_values, 'g', label='Validation loss')

plt.title('Training and validation loss')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend()

plt.subplot(122)
plt.plot(epochs, acc_values, 'r.', label='Training acc')
plt.plot(epochs, val_acc_values, 'r', label='Validation acc')
plt.title('Training and validation accuracy')
plt.xlabel('Epochs')
plt.ylabel('Accuracy')
plt.legend()
plt.show()

# %% [markdown]
# # Base Model Results

# %%
test_accu = cnn.evaluate(test_set)
# Out:
# 87/87 [==============================] - 24s 272ms/step - loss: 0.5428 - accuracy: 0.7419 - precision: 0.8347 - recall: 0.6000

# %%
print('The testing accuracy is :',test_accu[1]*100, '%')
# Out:
# The testing accuracy is : 74.188894033432 %

# %%
# extract 9 random images from the test set
imageset = glob(test_dir + "*/*")
random_images = [np.random.choice(imageset) for i in range(9)]

print('Here are the actual classes for each image')
print(random_images)
print('Below are the predictions')

# adjust the size of the images
plt.figure(figsize=(10,8))

# iterate and plot random images
for i in range(9):
    plt.subplot(3, 3, i + 1)
    img = cv2.imread(random_images[i])
    orig = img.copy()
    img = cv2.resize(img, (300,300))
    img = img_to_array(img)
    img = np.expand_dims(img, axis=0)
    img = img/255
    prediction = cnn.predict(img)
    
    if (prediction < 0.5):
        plt.title("NOT_TOXIC", fontdict = {'fontsize' : 30})
    
    else:
        plt.title("TOXIC", fontdict = {'fontsize' : 30})
    plt.imshow(orig, cmap='gray')
    plt.axis('off')
    
# adjust subplot parameters to give specified padding
plt.tight_layout()
# Out:
# Here are the actual classes for each image
# ['mol_images/test/not_toxic/TOX529.jpg', 'mol_images/test/toxic/TOX6089 copy 21.jpg', 'mol_images/test/toxic/TOX26461 copy 10.jpg', 'mol_images/test/toxic/TOX25967 copy 3.jpg', 'mol_images/test/toxic/TOX5861 copy 5.jpg', 'mol_images/test/toxic/TOX3679 copy 19.jpg', 'mol_images/test/not_toxic/TOX24994.jpg', 'mol_images/test/not_toxic/TOX26868.jpg', 'mol_images/test/toxic/TOX2814 copy 22.jpg']
# Below are the predictions

# %% [markdown]
# # Transfer Learning - VGG16

# %%
# setting image size
img_rows, img_cols = 300, 300

model = vgg16.VGG16(weights= 'imagenet', include_top=False, input_shape= (img_rows, img_cols, 3))

# %%
# freezing the layers 
for layer in model.layers:
    layer.trainable = False

# %%
model.summary()
# Out:
# Model: "vgg16"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_1 (InputLayer)         [(None, 300, 300, 3)]     0
# _________________________________________________________________
# block1_conv1 (Conv2D)        (None, 300, 300, 64)      1792
# _________________________________________________________________
# block1_conv2 (Conv2D)        (None, 300, 300, 64)      36928
# _________________________________________________________________
# block1_pool (MaxPooling2D)   (None, 150, 150, 64)      0
# _________________________________________________________________
# block2_conv1 (Conv2D)        (None, 150, 150, 128)     73856
# _________________________________________________________________
# block2_conv2 (Conv2D)        (None, 150, 150, 128)     147584
# _________________________________________________________________
# block2_pool (MaxPooling2D)   (None, 75, 75, 128)       0
# _________________________________________________________________
# block3_conv1 (Conv2D)        (None, 75, 75, 256)       295168
# _________________________________________________________________
# block3_conv2 (Conv2D)        (None, 75, 75, 256)       590080
# _________________________________________________________________
# block3_conv3 (Conv2D)        (None, 75, 75, 256)       590080
# _________________________________________________________________
# block3_pool (MaxPooling2D)   (None, 37, 37, 256)       0
# _________________________________________________________________
# block4_conv1 (Conv2D)        (None, 37, 37, 512)       1180160
# _________________________________________________________________
# block4_conv2 (Conv2D)        (None, 37, 37, 512)       2359808
# _________________________________________________________________
# block4_conv3 (Conv2D)        (None, 37, 37, 512)       2359808
# _________________________________________________________________
# block4_pool (MaxPooling2D)   (None, 18, 18, 512)       0
# _________________________________________________________________
# block5_conv1 (Conv2D)        (None, 18, 18, 512)       2359808
# _________________________________________________________________
# block5_conv2 (Conv2D)        (None, 18, 18, 512)       2359808
# _________________________________________________________________
# block5_conv3 (Conv2D)        (None, 18, 18, 512)       2359808
# _________________________________________________________________
# block5_pool (MaxPooling2D)   (None, 9, 9, 512)         0
# =================================================================
# Total params: 14,714,688
# Trainable params: 0
# Non-trainable params: 14,714,688
# _________________________________________________________________

# %%
# adding additional layers for hyperparameter tuning

def layer_adder(bottom_model, num_classes):
    top_model = bottom_model.output
    top_model = GlobalAveragePooling2D()(top_model)
    top_model = Dense(1024, activation='relu')(top_model)
    top_model = Dense(512, activation='relu')(top_model)
    top_model = Dense(1, activation='sigmoid')(top_model)
    return top_model

# %%
# pulling together the entire model

num_classes = 1

FC_Head = layer_adder(model, num_classes)

model = Model(inputs = model.input, outputs = FC_Head)

print(model.summary())
# Out:
# Model: "model"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_1 (InputLayer)         [(None, 300, 300, 3)]     0
# _________________________________________________________________
# block1_conv1 (Conv2D)        (None, 300, 300, 64)      1792
# _________________________________________________________________
# block1_conv2 (Conv2D)        (None, 300, 300, 64)      36928
# _________________________________________________________________
# block1_pool (MaxPooling2D)   (None, 150, 150, 64)      0
# _________________________________________________________________
# block2_conv1 (Conv2D)        (None, 150, 150, 128)     73856
# _________________________________________________________________
# block2_conv2 (Conv2D)        (None, 150, 150, 128)     147584
# _________________________________________________________________
# block2_pool (MaxPooling2D)   (None, 75, 75, 128)       0
# _________________________________________________________________
# block3_conv1 (Conv2D)        (None, 75, 75, 256)       295168
# _________________________________________________________________
# block3_conv2 (Conv2D)        (None, 75, 75, 256)       590080
# _________________________________________________________________
# block3_conv3 (Conv2D)        (None, 75, 75, 256)       590080
# _________________________________________________________________
# block3_pool (MaxPooling2D)   (None, 37, 37, 256)       0
# _________________________________________________________________
# block4_conv1 (Conv2D)        (None, 37, 37, 512)       1180160
# _________________________________________________________________
# block4_conv2 (Conv2D)        (None, 37, 37, 512)       2359808
# _________________________________________________________________
# block4_conv3 (Conv2D)        (None, 37, 37, 512)       2359808
# _________________________________________________________________
# block4_pool (MaxPooling2D)   (None, 18, 18, 512)       0
# _________________________________________________________________
# block5_conv1 (Conv2D)        (None, 18, 18, 512)       2359808
# _________________________________________________________________
# block5_conv2 (Conv2D)        (None, 18, 18, 512)       2359808
# _________________________________________________________________
# block5_conv3 (Conv2D)        (None, 18, 18, 512)       2359808
# _________________________________________________________________
# block5_pool (MaxPooling2D)   (None, 9, 9, 512)         0
# _________________________________________________________________
# global_average_pooling2d (Gl (None, 512)               0
# _________________________________________________________________
# dense_3 (Dense)              (None, 1024)              525312
# _________________________________________________________________
# dense_4 (Dense)              (None, 512)               524800
# _________________________________________________________________
# dense_5 (Dense)              (None, 1)                 513
# =================================================================
# Total params: 15,765,313
# Trainable params: 1,050,625
# Non-trainable params: 14,714,688
# _________________________________________________________________
# None

# %% [markdown]
# # Fitting the Model

# %%
checkpoint = ModelCheckpoint('face_detector.h15', monitor= 'val_loss', mode= 'min', save_best_only = True, verbose= 1)
earlystop = EarlyStopping(monitor= 'val_loss', min_delta= 0, patience= 3, verbose = 1, restore_best_weights= True)
callbacks = [earlystop, checkpoint]

model.compile(loss = 'binary_crossentropy', optimizer = 'Adam', metrics=['accuracy',tf.keras.metrics.Precision(name='precision'),
                     tf.keras.metrics.Recall(name='recall')])

nb_train_samples = 5811
nb_validation_samples = 725

epochs = 10
batch_size = 16

history = model.fit(training_set, epochs= epochs, callbacks = callbacks, validation_data= val_set)
# Out:
# Epoch 1/10
# 700/700 [==============================] - ETA: 0s - loss: 0.5376 - accuracy: 0.7189 - precision: 0.7668 - recall: 0.6343
# Epoch 00001: val_loss improved from inf to 0.64914, saving model to face_detector.h15
# WARNING:tensorflow:From /opt/anaconda3/lib/python3.7/site-packages/tensorflow/python/ops/resource_variable_ops.py:1817: calling BaseResourceVariable.__init__ (from tensorflow.python.ops.resource_variable_ops) with constraint is deprecated and will be removed in a future version.
# Instructions for updating:
# If using Keras pass *_constraint arguments to layers.
# INFO:tensorflow:Assets written to: face_detector.h15/assets
# 700/700 [==============================] - 2652s 4s/step - loss: 0.5376 - accuracy: 0.7189 - precision: 0.7668 - recall: 0.6343 - val_loss: 0.6491 - val_accuracy: 0.6222 - val_precision: 0.8145 - val_recall: 0.3200
# Epoch 2/10
# 700/700 [==============================] - ETA: 0s - loss: 0.5001 - accuracy: 0.7354 - precision: 0.8175 - recall: 0.6105
# Epoch 00002: val_loss did not improve from 0.64914
# 700/700 [==============================] - 2648s 4s/step - loss: 0.5001 - accuracy: 0.7354 - precision: 0.8175 - recall: 0.6105 - val_loss: 0.6703 - val_accuracy: 0.6172 - val_precision: 0.7943 - val_recall: 0.3200
# Epoch 3/10
# 700/700 [==============================] - ETA: 0s - loss: 0.4896 - accuracy: 0.7448 - precision: 0.8424 - recall: 0.6062
# Epoch 00003: val_loss did not improve from 0.64914
# 700/700 [==============================] - 2646s 4s/step - loss: 0.4896 - accuracy: 0.7448 - precision: 0.8424 - recall: 0.6062 - val_loss: 0.6502 - val_accuracy: 0.6824 - val_precision: 0.7438 - val_recall: 0.5600
# Epoch 4/10
# 700/700 [==============================] - ETA: 0s - loss: 0.4723 - accuracy: 0.7479 - precision: 0.8319 - recall: 0.6254Restoring model weights from the end of the best epoch.
#
# Epoch 00004: val_loss did not improve from 0.64914
# 700/700 [==============================] - 2642s 4s/step - loss: 0.4723 - accuracy: 0.7479 - precision: 0.8319 - recall: 0.6254 - val_loss: 0.6520 - val_accuracy: 0.6115 - val_precision: 0.7283 - val_recall: 0.3600
# Epoch 00004: early stopping

# %% [markdown]
# # Transfer Learning Model Results

# %%
test_accu = model.evaluate(test_set)
# Out:
# 87/87 [==============================] - 285s 3s/step - loss: 0.5312 - accuracy: 0.7203 - precision: 0.8892 - recall: 0.5000

# %%
print('The testing accuracy is :',test_accu[1]*100, '%')
# Out:
# The testing accuracy is : 72.02595472335815 %

# %%
# summarize history for accuracy
plt.plot(history.history['accuracy'])
plt.plot(history.history['val_accuracy'])
plt.title('model accuracy')
plt.ylabel('accuracy')
plt.xlabel('epoch')
plt.legend(['train', 'val'], loc='best')
plt.show()

#summarize history for loss
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title('model loss')
plt.ylabel('loss')
plt.xlabel('epoch')
plt.legend(['train', 'val'], loc='best')
plt.show()

# %%
# extract 9 random images from the test set
imageset = glob(test_dir + "*/*")
random_images = [np.random.choice(imageset) for i in range(9)]

print('Here are the actual classes for each image')
print(random_images)
print('Below are the predictions')

# adjust the size of your images
plt.figure(figsize=(10,8))

# iterate and plot random images
for i in range(9):
    plt.subplot(3, 3, i + 1)
    img = cv2.imread(random_images[i])
    orig = img.copy()
    img = cv2.resize(img, (300,300))
    img = img_to_array(img)
    img = np.expand_dims(img, axis=0)
    img = img/255
    prediction = model.predict(img)
    
    if (prediction < 0.5):
        plt.title("NOT_TOXIC", fontdict = {'fontsize' : 30})
    
    else:
        plt.title("TOXIC", fontdict = {'fontsize' : 30})
    plt.imshow(orig, cmap='gray')
    plt.axis('off')
    
# adjust subplot parameters to give specified padding
plt.tight_layout()
# Out:
# Here are the actual classes for each image
# ['mol_images/test/not_toxic/TOX26108.jpg', 'mol_images/test/toxic/TOX283 copy 12.jpg', 'mol_images/test/not_toxic/TOX2736.jpg', 'mol_images/test/toxic/TOX283 copy 17.jpg', 'mol_images/test/not_toxic/TOX29290.jpg', 'mol_images/test/not_toxic/TOX25582.jpg', 'mol_images/test/toxic/TOX27006 copy 17.jpg', 'mol_images/test/not_toxic/TOX238.jpg', 'mol_images/test/not_toxic/TOX24215.jpg']
# Below are the predictions

# %% [markdown]
# # Xception

# %%
dontrun()

# %%
def create_model():
    pretrained_model = tf.keras.applications.Xception(input_shape=[300, 300, 3], include_top=False)
    pretrained_model.trainable = True

    model = tf.keras.Sequential([
        pretrained_model,
        tf.keras.layers.GlobalAveragePooling2D(),
        #tf.keras.layers.Flatten(),
        tf.keras.layers.Dense(1, activation='sigmoid', dtype=tf.float32) # the float32 is needed on softmax layer when using mixed precision
    ])

    model.compile(
        optimizer='adam',
        loss = 'categorical_crossentropy',
        metrics=['accuracy']
    )

    return model

# %%
Xmodel = create_model()
Xmodel.summary()
# Out:
# Model: "sequential_2"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# xception (Model)             (None, 10, 10, 2048)      20861480
# _________________________________________________________________
# global_average_pooling2d_2 ( (None, 2048)              0
# _________________________________________________________________
# dense_7 (Dense)              (None, 1)                 2049
# =================================================================
# Total params: 20,863,529
# Trainable params: 20,809,001
# Non-trainable params: 54,528
# _________________________________________________________________

# %%
history = Xmodel.fit(training_set, validation_data=val_set,
                    epochs=5, workers=-1, verbose=1)

final_accuracy = history.history["val_accuracy"]
print("FINAL ACCURACY MEAN-5: ", np.mean(final_accuracy))
# Out:
# Epoch 1/5
# 700/700 [==============================] - 4928s 7s/step - loss: 5.9983e-08 - accuracy: 0.5084 - val_loss: 5.9818e-08 - val_accuracy: 0.4889
# Epoch 2/5
# 700/700 [==============================] - 4947s 7s/step - loss: 5.9983e-08 - accuracy: 0.5072 - val_loss: 5.9818e-08 - val_accuracy: 0.4681
# Epoch 3/5
# 700/700 [==============================] - 5057s 7s/step - loss: 5.9983e-08 - accuracy: 0.5077 - val_loss: 5.9818e-08 - val_accuracy: 0.4882
# Epoch 4/5
# 700/700 [==============================] - 5209s 7s/step - loss: 5.9983e-08 - accuracy: 0.5122 - val_loss: 5.9818e-08 - val_accuracy: 0.4882
# Epoch 5/5
# 700/700 [==============================] - 5266s 8s/step - loss: 5.9983e-08 - accuracy: 0.5095 - val_loss: 5.9818e-08 - val_accuracy: 0.4882
# FINAL ACCURACY MEAN-5:  0.48430108428001406

# %%
# summarize history for accuracy
plt.plot(history.history['accuracy'])
plt.plot(history.history['val_accuracy'])
plt.title('model accuracy')
plt.ylabel('accuracy')
plt.xlabel('epoch')
plt.legend(['train', 'val'], loc='best')
plt.show()

#summarize history for loss
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title('model loss')
plt.ylabel('loss')
plt.xlabel('epoch')
plt.legend(['train', 'val'], loc='best')
plt.show()

# %%
# extract 9 random images from the test set
imageset = glob(test_dir + "*/*")
random_images = [np.random.choice(imageset) for i in range(9)]

print('Here are the actual classes for each image')
print(random_images)
print('Below are the predictions')

# adjust the size of your images
plt.figure(figsize=(10,8))

# iterate and plot random images
for i in range(9):
    plt.subplot(3, 3, i + 1)
    img = cv2.imread(random_images[i])
    orig = img.copy()
    img = cv2.resize(img, (300,300))
    img = img_to_array(img)
    img = np.expand_dims(img, axis=0)
    img = img/255
    prediction = model.predict(img)
    
    if (prediction < 0.5):
        plt.title("NOT_TOXIC", fontdict = {'fontsize' : 30})
    
    else:
        plt.title("TOXIC", fontdict = {'fontsize' : 30})
    plt.imshow(orig, cmap='gray')
    plt.axis('off')
    
# adjust subplot parameters to give specified padding
plt.tight_layout()
# Out:
# Here are the actual classes for each image
# ['mol_images/test/not_toxic/TOX743.jpg', 'mol_images/test/not_toxic/TOX26924.jpg', 'mol_images/test/not_toxic/TOX9290.jpg', 'mol_images/test/toxic/TOX25633 copy 2.jpg', 'mol_images/test/toxic/TOX11980 copy 11.jpg', 'mol_images/test/not_toxic/TOX3615.jpg', 'mol_images/test/not_toxic/TOX27043.jpg', 'mol_images/test/toxic/TOX2814 copy 7.jpg', 'mol_images/test/toxic/TOX28898 copy 6.jpg']
# Below are the predictions
